# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/17marchm1/pixelwarunet_model1.pth
# /kaggle/input/train1/Train/low/641.png
# /kaggle/input/train1/Train/low/173.png
# /kaggle/input/train1/Train/low/491.png
# /kaggle/input/train1/Train/low/718.png
# /kaggle/input/train1/Train/low/709.png
# /kaggle/input/train1/Train/low/248.png
# /kaggle/input/train1/Train/low/94.png
# /kaggle/input/train1/Train/low/480.png
# /kaggle/input/train1/Train/low/236.png
# /kaggle/input/train1/Train/low/771.png
# /kaggle/input/train1/Train/low/675.png
# /kaggle/input/train1/Train/low/48.png
# /kaggle/input/train1/Train/low/677.png
# /kaggle/input/train1/Train/low/761.png
# /kaggle/input/train1/Train/low/655.png
# /kaggle/input/train1/Train/low/227.png
# /kaggle/input/train1/Train/low/762.png
# /kaggle/input/train1/Train/low/726.png
# /kaggle/input/train1/Train/low/238.png
# /kaggle/input/train1/Train/low/61.png
# /kaggle/input/train1/Train/low/222.png
# /kaggle/input/train1/Train/low/330.png
# /kaggle/input/train1/Train/low/511.png
# /kaggle/input/train1/Train/low/579.png
# /kaggle/input/train1/Train/low/231.png
# /kaggle/input/train1/Train/low/645.png
# /kaggle/input/train1/Train/low/621.png
# /kaggle/input/train1/Train/low/35.png
# /kaggle/input/train1/Train/low/232.png
# /kaggle/input/train1/Train/low/142.png
# /kaggle/input/train1/Train/low/104.png
# /kaggle/input/train1/Train/low/543.png
# /kaggle/input/train1/Train/low/737.png
# /kaggle/input/train1/Train/low/70.png
# /kaggle/input/train1/Train/low/162.png
# /kaggle/input/train1/Train/low/517.png
# /kaggle/input/train1/Train/low/634.png
# /kaggle/input/train1/Train/low/186.png
# /kaggle/input/train1/Train/low/73.png
# /kaggle/input/train1/Train/low/92.png
# /kaggle/input/train1/Train/low/542.png
# /kaggle/input/train1/Train/low/766.png
# /kaggle/input/train1/Train/low/261.png
# /kaggle/input/train1/Train/low/167.png
# /kaggle/input/train1/Train/low/628.png
# /kaggle/input/train1/Train/low/506.png
# /kaggle/input/train1/Train/low/562.png
# /kaggle/input/train1/Train/low/681.png
# /kaggle/input/train1/Train/low/204.png
# /kaggle/input/train1/Train/low/646.png
# /kaggle/input/train1/Train/low/75.png
# /kaggle/input/train1/Train/low/744.png
# /kaggle/input/train1/Train/low/538.png
# /kaggle/input/train1/Train/low/651.png
# /kaggle/input/train1/Train/low/89.png
# /kaggle/input/train1/Train/low/752.png
# /kaggle/input/train1/Train/low/550.png
# /kaggle/input/train1/Train/low/615.png
# /kaggle/input/train1/Train/low/605.png
# /kaggle/input/train1/Train/low/213.png
# /kaggle/input/train1/Train/low/505.png
# /kaggle/input/train1/Train/low/114.png
# /kaggle/input/train1/Train/low/185.png
# /kaggle/input/train1/Train/low/240.png
# /kaggle/input/train1/Train/low/344.png
# /kaggle/input/train1/Train/low/759.png
# /kaggle/input/train1/Train/low/176.png
# /kaggle/input/train1/Train/low/660.png
# /kaggle/input/train1/Train/low/727.png
# /kaggle/input/train1/Train/low/95.png
# /kaggle/input/train1/Train/low/97.png
# /kaggle/input/train1/Train/low/124.png
# /kaggle/input/train1/Train/low/119.png
# /kaggle/input/train1/Train/low/654.png
# /kaggle/input/train1/Train/low/100.png
# /kaggle/input/train1/Train/low/211.png
# /kaggle/input/train1/Train/low/500.png
# /kaggle/input/train1/Train/low/76.png
# /kaggle/input/train1/Train/low/193.png
# /kaggle/input/train1/Train/low/608.png
# /kaggle/input/train1/Train/low/191.png
# /kaggle/input/train1/Train/low/528.png
# /kaggle/input/train1/Train/low/623.png
# /kaggle/input/train1/Train/low/642.png
# /kaggle/input/train1/Train/low/138.png
# /kaggle/input/train1/Train/low/629.png
# /kaggle/input/train1/Train/low/225.png
# /kaggle/input/train1/Train/low/561.png
# /kaggle/input/train1/Train/low/588.png
# /kaggle/input/train1/Train/low/492.png
# /kaggle/input/train1/Train/low/43.png
# /kaggle/input/train1/Train/low/229.png
# /kaggle/input/train1/Train/low/129.png
# /kaggle/input/train1/Train/low/580.png
# /kaggle/input/train1/Train/low/171.png
# /kaggle/input/train1/Train/low/682.png
# /kaggle/input/train1/Train/low/145.png
# /kaggle/input/train1/Train/low/40.png
# /kaggle/input/train1/Train/low/209.png
# /kaggle/input/train1/Train/low/575.png
# /kaggle/input/train1/Train/low/33.png
# /kaggle/input/train1/Train/low/126.png
# /kaggle/input/train1/Train/low/147.png
# /kaggle/input/train1/Train/low/688.png
# /kaggle/input/train1/Train/low/468.png
# /kaggle/input/train1/Train/low/9.png
# /kaggle/input/train1/Train/low/604.png
# /kaggle/input/train1/Train/low/102.png
# /kaggle/input/train1/Train/low/254.png
# /kaggle/input/train1/Train/low/658.png
# /kaggle/input/train1/Train/low/647.png
# /kaggle/input/train1/Train/low/689.png
# /kaggle/input/train1/Train/low/233.png
# /kaggle/input/train1/Train/low/200.png
# /kaggle/input/train1/Train/low/743.png
# /kaggle/input/train1/Train/low/713.png
# /kaggle/input/train1/Train/low/546.png
# /kaggle/input/train1/Train/low/56.png
# /kaggle/input/train1/Train/low/515.png
# /kaggle/input/train1/Train/low/578.png
# /kaggle/input/train1/Train/low/116.png
# /kaggle/input/train1/Train/low/555.png
# /kaggle/input/train1/Train/low/533.png
# /kaggle/input/train1/Train/low/488.png
# /kaggle/input/train1/Train/low/80.png
# /kaggle/input/train1/Train/low/698.png
# /kaggle/input/train1/Train/low/130.png
# /kaggle/input/train1/Train/low/592.png
# /kaggle/input/train1/Train/low/586.png
# /kaggle/input/train1/Train/low/522.png
# /kaggle/input/train1/Train/low/50.png
# /kaggle/input/train1/Train/low/607.png
# /kaggle/input/train1/Train/low/779.png
# /kaggle/input/train1/Train/low/199.png
# /kaggle/input/train1/Train/low/112.png
# /kaggle/input/train1/Train/low/763.png
# /kaggle/input/train1/Train/low/788.png
# /kaggle/input/train1/Train/low/501.png
# /kaggle/input/train1/Train/low/723.png
# /kaggle/input/train1/Train/low/747.png
# /kaggle/input/train1/Train/low/552.png
# /kaggle/input/train1/Train/low/775.png
# /kaggle/input/train1/Train/low/93.png
# /kaggle/input/train1/Train/low/150.png
# /kaggle/input/train1/Train/low/774.png
# /kaggle/input/train1/Train/low/113.png
# /kaggle/input/train1/Train/low/741.png
# /kaggle/input/train1/Train/low/59.png
# /kaggle/input/train1/Train/low/674.png
# /kaggle/input/train1/Train/low/785.png
# /kaggle/input/train1/Train/low/169.png
# /kaggle/input/train1/Train/low/529.png
# /kaggle/input/train1/Train/low/194.png
# /kaggle/input/train1/Train/low/136.png
# /kaggle/input/train1/Train/low/198.png
# /kaggle/input/train1/Train/low/724.png
# /kaggle/input/train1/Train/low/683.png
# /kaggle/input/train1/Train/low/640.png
# /kaggle/input/train1/Train/low/14.png
# /kaggle/input/train1/Train/low/784.png
# /kaggle/input/train1/Train/low/576.png
# /kaggle/input/train1/Train/low/574.png
# /kaggle/input/train1/Train/low/701.png
# /kaggle/input/train1/Train/low/484.png
# /kaggle/input/train1/Train/low/39.png
# /kaggle/input/train1/Train/low/610.png
# /kaggle/input/train1/Train/low/132.png
# /kaggle/input/train1/Train/low/781.png
# /kaggle/input/train1/Train/low/715.png
# /kaggle/input/train1/Train/low/549.png
# /kaggle/input/train1/Train/low/777.png
# /kaggle/input/train1/Train/low/696.png
# /kaggle/input/train1/Train/low/609.png
# /kaggle/input/train1/Train/low/107.png
# /kaggle/input/train1/Train/low/262.png
# /kaggle/input/train1/Train/low/215.png
# /kaggle/input/train1/Train/low/769.png
# /kaggle/input/train1/Train/low/614.png
# /kaggle/input/train1/Train/low/471.png
# /kaggle/input/train1/Train/low/83.png
# /kaggle/input/train1/Train/low/597.png
# /kaggle/input/train1/Train/low/473.png
# /kaggle/input/train1/Train/low/587.png
# /kaggle/input/train1/Train/low/770.png
# /kaggle/input/train1/Train/low/731.png
# /kaggle/input/train1/Train/low/691.png
# /kaggle/input/train1/Train/low/38.png
# /kaggle/input/train1/Train/low/151.png
# /kaggle/input/train1/Train/low/2.png
# /kaggle/input/train1/Train/low/530.png
# /kaggle/input/train1/Train/low/702.png
# /kaggle/input/train1/Train/low/10.png
# /kaggle/input/train1/Train/low/598.png
# /kaggle/input/train1/Train/low/82.png
# /kaggle/input/train1/Train/low/460.png
# /kaggle/input/train1/Train/low/242.png
# /kaggle/input/train1/Train/low/251.png
# /kaggle/input/train1/Train/low/174.png
# /kaggle/input/train1/Train/low/250.png
# /kaggle/input/train1/Train/low/131.png
# /kaggle/input/train1/Train/low/36.png
# /kaggle/input/train1/Train/low/157.png
# /kaggle/input/train1/Train/low/143.png
# /kaggle/input/train1/Train/low/221.png
# /kaggle/input/train1/Train/low/746.png
# /kaggle/input/train1/Train/low/570.png
# /kaggle/input/train1/Train/low/700.png
# /kaggle/input/train1/Train/low/152.png
# /kaggle/input/train1/Train/low/137.png
# /kaggle/input/train1/Train/low/556.png
# /kaggle/input/train1/Train/low/81.png
# /kaggle/input/train1/Train/low/239.png
# /kaggle/input/train1/Train/low/58.png
# /kaggle/input/train1/Train/low/661.png
# /kaggle/input/train1/Train/low/483.png
# /kaggle/input/train1/Train/low/764.png
# /kaggle/input/train1/Train/low/732.png
# /kaggle/input/train1/Train/low/122.png
# /kaggle/input/train1/Train/low/639.png
# /kaggle/input/train1/Train/low/684.png
# /kaggle/input/train1/Train/low/712.png
# /kaggle/input/train1/Train/low/735.png
# /kaggle/input/train1/Train/low/734.png
# /kaggle/input/train1/Train/low/722.png
# /kaggle/input/train1/Train/low/187.png
# /kaggle/input/train1/Train/low/106.png
# /kaggle/input/train1/Train/low/585.png
# /kaggle/input/train1/Train/low/117.png
# /kaggle/input/train1/Train/low/220.png
# /kaggle/input/train1/Train/low/617.png
# /kaggle/input/train1/Train/low/667.png
# /kaggle/input/train1/Train/low/244.png
# /kaggle/input/train1/Train/low/263.png
# /kaggle/input/train1/Train/low/650.png
# /kaggle/input/train1/Train/low/594.png
# /kaggle/input/train1/Train/low/680.png
# /kaggle/input/train1/Train/low/572.png
# /kaggle/input/train1/Train/low/18.png
# /kaggle/input/train1/Train/low/63.png
# /kaggle/input/train1/Train/low/534.png
# /kaggle/input/train1/Train/low/745.png
# /kaggle/input/train1/Train/low/264.png
# /kaggle/input/train1/Train/low/21.png
# /kaggle/input/train1/Train/low/495.png
# /kaggle/input/train1/Train/low/12.png
# /kaggle/input/train1/Train/low/739.png
# /kaggle/input/train1/Train/low/514.png
# /kaggle/input/train1/Train/low/616.png
# /kaggle/input/train1/Train/low/720.png
# /kaggle/input/train1/Train/low/98.png
# /kaggle/input/train1/Train/low/524.png
# /kaggle/input/train1/Train/low/127.png
# /kaggle/input/train1/Train/low/666.png
# /kaggle/input/train1/Train/low/553.png
# /kaggle/input/train1/Train/low/219.png
# /kaggle/input/train1/Train/low/184.png
# /kaggle/input/train1/Train/low/782.png
# /kaggle/input/train1/Train/low/757.png
# /kaggle/input/train1/Train/low/627.png
# /kaggle/input/train1/Train/low/751.png
# /kaggle/input/train1/Train/low/28.png
# /kaggle/input/train1/Train/low/490.png
# /kaggle/input/train1/Train/low/464.png
# /kaggle/input/train1/Train/low/202.png
# /kaggle/input/train1/Train/low/247.png
# /kaggle/input/train1/Train/low/758.png
# /kaggle/input/train1/Train/low/469.png
# /kaggle/input/train1/Train/low/476.png
# /kaggle/input/train1/Train/low/481.png
# /kaggle/input/train1/Train/low/559.png
# /kaggle/input/train1/Train/low/625.png
# /kaggle/input/train1/Train/low/67.png
# /kaggle/input/train1/Train/low/96.png
# /kaggle/input/train1/Train/low/243.png
# /kaggle/input/train1/Train/low/502.png
# /kaggle/input/train1/Train/low/690.png
# /kaggle/input/train1/Train/low/733.png
# /kaggle/input/train1/Train/low/159.png
# /kaggle/input/train1/Train/low/662.png
# /kaggle/input/train1/Train/low/563.png
# /kaggle/input/train1/Train/low/551.png
# /kaggle/input/train1/Train/low/685.png
# /kaggle/input/train1/Train/low/554.png
# /kaggle/input/train1/Train/low/596.png
# /kaggle/input/train1/Train/low/246.png
# /kaggle/input/train1/Train/low/195.png
# /kaggle/input/train1/Train/low/105.png
# /kaggle/input/train1/Train/low/479.png
# /kaggle/input/train1/Train/low/612.png
# /kaggle/input/train1/Train/low/125.png
# /kaggle/input/train1/Train/low/121.png
# /kaggle/input/train1/Train/low/216.png
# /kaggle/input/train1/Train/low/69.png
# /kaggle/input/train1/Train/low/154.png
# /kaggle/input/train1/Train/low/637.png
# /kaggle/input/train1/Train/low/267.png
# /kaggle/input/train1/Train/low/663.png
# /kaggle/input/train1/Train/low/241.png
# /kaggle/input/train1/Train/low/188.png
# /kaggle/input/train1/Train/low/716.png
# /kaggle/input/train1/Train/low/86.png
# /kaggle/input/train1/Train/low/776.png
# /kaggle/input/train1/Train/low/258.png
# /kaggle/input/train1/Train/low/77.png
# /kaggle/input/train1/Train/low/498.png
# /kaggle/input/train1/Train/low/265.png
# /kaggle/input/train1/Train/low/638.png
# /kaggle/input/train1/Train/low/103.png
# /kaggle/input/train1/Train/low/144.png
# /kaggle/input/train1/Train/low/472.png
# /kaggle/input/train1/Train/low/695.png
# /kaggle/input/train1/Train/low/644.png
# /kaggle/input/train1/Train/low/540.png
# /kaggle/input/train1/Train/low/109.png
# /kaggle/input/train1/Train/low/496.png
# /kaggle/input/train1/Train/low/714.png
# /kaggle/input/train1/Train/low/697.png
# /kaggle/input/train1/Train/low/567.png
# /kaggle/input/train1/Train/low/526.png
# /kaggle/input/train1/Train/low/527.png
# /kaggle/input/train1/Train/low/648.png
# /kaggle/input/train1/Train/low/595.png
# /kaggle/input/train1/Train/low/573.png
# /kaggle/input/train1/Train/low/74.png
# /kaggle/input/train1/Train/low/653.png
# /kaggle/input/train1/Train/low/525.png
# /kaggle/input/train1/Train/low/120.png
# /kaggle/input/train1/Train/low/630.png
# /kaggle/input/train1/Train/low/118.png
# /kaggle/input/train1/Train/low/772.png
# /kaggle/input/train1/Train/low/670.png
# /kaggle/input/train1/Train/low/17.png
# /kaggle/input/train1/Train/low/53.png
# /kaggle/input/train1/Train/low/486.png
# /kaggle/input/train1/Train/low/196.png
# /kaggle/input/train1/Train/low/626.png
# /kaggle/input/train1/Train/low/571.png
# /kaggle/input/train1/Train/low/160.png
# /kaggle/input/train1/Train/low/671.png
# /kaggle/input/train1/Train/low/140.png
# /kaggle/input/train1/Train/low/620.png
# /kaggle/input/train1/Train/low/736.png
# /kaggle/input/train1/Train/low/52.png
# /kaggle/input/train1/Train/low/5.png
# /kaggle/input/train1/Train/low/139.png
# /kaggle/input/train1/Train/low/172.png
# /kaggle/input/train1/Train/low/64.png
# /kaggle/input/train1/Train/low/719.png
# /kaggle/input/train1/Train/low/16.png
# /kaggle/input/train1/Train/low/545.png
# /kaggle/input/train1/Train/low/725.png
# /kaggle/input/train1/Train/low/328.png
# /kaggle/input/train1/Train/low/643.png
# /kaggle/input/train1/Train/low/760.png
# /kaggle/input/train1/Train/low/203.png
# /kaggle/input/train1/Train/low/489.png
# /kaggle/input/train1/Train/low/45.png
# /kaggle/input/train1/Train/low/24.png
# /kaggle/input/train1/Train/low/548.png
# /kaggle/input/train1/Train/low/88.png
# /kaggle/input/train1/Train/low/649.png
# /kaggle/input/train1/Train/low/624.png
# /kaggle/input/train1/Train/low/115.png
# /kaggle/input/train1/Train/low/249.png
# /kaggle/input/train1/Train/low/128.png
# /kaggle/input/train1/Train/low/668.png
# /kaggle/input/train1/Train/low/583.png
# /kaggle/input/train1/Train/low/710.png
# /kaggle/input/train1/Train/low/6.png
# /kaggle/input/train1/Train/low/87.png
# /kaggle/input/train1/Train/low/686.png
# /kaggle/input/train1/Train/low/787.png
# /kaggle/input/train1/Train/low/51.png
# /kaggle/input/train1/Train/low/703.png
# /kaggle/input/train1/Train/low/728.png
# /kaggle/input/train1/Train/low/591.png
# /kaggle/input/train1/Train/low/101.png
# /kaggle/input/train1/Train/low/606.png
# /kaggle/input/train1/Train/low/717.png
# /kaggle/input/train1/Train/low/135.png
# /kaggle/input/train1/Train/low/482.png
# /kaggle/input/train1/Train/low/740.png
# /kaggle/input/train1/Train/low/512.png
# /kaggle/input/train1/Train/low/123.png
# /kaggle/input/train1/Train/low/91.png
# /kaggle/input/train1/Train/low/504.png
# /kaggle/input/train1/Train/low/230.png
# /kaggle/input/train1/Train/low/738.png
# /kaggle/input/train1/Train/low/478.png
# /kaggle/input/train1/Train/low/44.png
# /kaggle/input/train1/Train/low/189.png
# /kaggle/input/train1/Train/low/541.png
# /kaggle/input/train1/Train/low/601.png
# /kaggle/input/train1/Train/low/730.png
# /kaggle/input/train1/Train/low/68.png
# /kaggle/input/train1/Train/low/180.png
# /kaggle/input/train1/Train/low/46.png
# /kaggle/input/train1/Train/low/508.png
# /kaggle/input/train1/Train/low/499.png
# /kaggle/input/train1/Train/low/711.png
# /kaggle/input/train1/Train/low/664.png
# /kaggle/input/train1/Train/low/470.png
# /kaggle/input/train1/Train/low/57.png
# /kaggle/input/train1/Train/low/84.png
# /kaggle/input/train1/Train/low/475.png
# /kaggle/input/train1/Train/low/564.png
# /kaggle/input/train1/Train/low/687.png
# /kaggle/input/train1/Train/low/15.png
# /kaggle/input/train1/Train/low/210.png
# /kaggle/input/train1/Train/low/252.png
# /kaggle/input/train1/Train/low/531.png
# /kaggle/input/train1/Train/low/507.png
# /kaggle/input/train1/Train/low/704.png
# /kaggle/input/train1/Train/low/565.png
# /kaggle/input/train1/Train/low/679.png
# /kaggle/input/train1/Train/low/523.png
# /kaggle/input/train1/Train/low/183.png
# /kaggle/input/train1/Train/low/678.png
# /kaggle/input/train1/Train/low/450.png
# /kaggle/input/train1/Train/low/485.png
# /kaggle/input/train1/Train/low/708.png
# /kaggle/input/train1/Train/low/569.png
# /kaggle/input/train1/Train/low/622.png
# /kaggle/input/train1/Train/low/537.png
# /kaggle/input/train1/Train/low/783.png
# /kaggle/input/train1/Train/low/60.png
# /kaggle/input/train1/Train/low/235.png
# /kaggle/input/train1/Train/low/99.png
# /kaggle/input/train1/Train/low/765.png
# /kaggle/input/train1/Train/low/593.png
# /kaggle/input/train1/Train/low/676.png
# /kaggle/input/train1/Train/low/228.png
# /kaggle/input/train1/Train/low/27.png
# /kaggle/input/train1/Train/low/237.png
# /kaggle/input/train1/Train/low/692.png
# /kaggle/input/train1/Train/low/474.png
# /kaggle/input/train1/Train/low/201.png
# /kaggle/input/train1/Train/low/539.png
# /kaggle/input/train1/Train/low/773.png
# /kaggle/input/train1/Train/low/78.png
# /kaggle/input/train1/Train/low/212.png
# /kaggle/input/train1/Train/low/47.png
# /kaggle/input/train1/Train/low/786.png
# /kaggle/input/train1/Train/low/207.png
# /kaggle/input/train1/Train/low/149.png
# /kaggle/input/train1/Train/low/487.png
# /kaggle/input/train1/Train/low/13.png
# /kaggle/input/train1/Train/low/535.png
# /kaggle/input/train1/Train/low/260.png
# /kaggle/input/train1/Train/low/253.png
# /kaggle/input/train1/Train/low/206.png
# /kaggle/input/train1/Train/low/789.png
# /kaggle/input/train1/Train/low/557.png
# /kaggle/input/train1/Train/low/613.png
# /kaggle/input/train1/Train/low/600.png
# /kaggle/input/train1/Train/low/342.png
# /kaggle/input/train1/Train/low/721.png
# /kaggle/input/train1/Train/low/694.png
# /kaggle/input/train1/Train/low/590.png
# /kaggle/input/train1/Train/low/566.png
# /kaggle/input/train1/Train/low/259.png
# /kaggle/input/train1/Train/low/25.png
# /kaggle/input/train1/Train/low/54.png
# /kaggle/input/train1/Train/low/558.png
# /kaggle/input/train1/Train/low/611.png
# /kaggle/input/train1/Train/low/62.png
# /kaggle/input/train1/Train/low/699.png
# /kaggle/input/train1/Train/low/750.png
# /kaggle/input/train1/Train/low/141.png
# /kaggle/input/train1/Train/low/693.png
# /kaggle/input/train1/Train/low/532.png
# /kaggle/input/train1/Train/low/560.png
# /kaggle/input/train1/Train/low/110.png
# /kaggle/input/train1/Train/low/544.png
# /kaggle/input/train1/Train/low/26.png
# /kaggle/input/train1/Train/low/568.png
# /kaggle/input/train1/Train/low/633.png
# /kaggle/input/train1/Train/low/729.png
# /kaggle/input/train1/Train/low/257.png
# /kaggle/input/train1/Train/low/477.png
# /kaggle/input/train1/Train/low/42.png
# /kaggle/input/train1/Train/low/175.png
# /kaggle/input/train1/Train/low/494.png
# /kaggle/input/train1/Train/low/659.png
# /kaggle/input/train1/Train/low/497.png
# /kaggle/input/train1/Train/high/641.png
# /kaggle/input/train1/Train/high/173.png
# /kaggle/input/train1/Train/high/491.png
# /kaggle/input/train1/Train/high/718.png
# /kaggle/input/train1/Train/high/709.png
# /kaggle/input/train1/Train/high/248.png
# /kaggle/input/train1/Train/high/94.png
# /kaggle/input/train1/Train/high/480.png
# /kaggle/input/train1/Train/high/236.png
# /kaggle/input/train1/Train/high/771.png
# /kaggle/input/train1/Train/high/675.png
# /kaggle/input/train1/Train/high/48.png
# /kaggle/input/train1/Train/high/677.png
# /kaggle/input/train1/Train/high/761.png
# /kaggle/input/train1/Train/high/655.png
# /kaggle/input/train1/Train/high/227.png
# /kaggle/input/train1/Train/high/762.png
# /kaggle/input/train1/Train/high/726.png
# /kaggle/input/train1/Train/high/238.png
# /kaggle/input/train1/Train/high/61.png
# /kaggle/input/train1/Train/high/222.png
# /kaggle/input/train1/Train/high/330.png
# /kaggle/input/train1/Train/high/511.png
# /kaggle/input/train1/Train/high/579.png
# /kaggle/input/train1/Train/high/231.png
# /kaggle/input/train1/Train/high/645.png
# /kaggle/input/train1/Train/high/621.png
# /kaggle/input/train1/Train/high/35.png
# /kaggle/input/train1/Train/high/232.png
# /kaggle/input/train1/Train/high/142.png
# /kaggle/input/train1/Train/high/104.png
# /kaggle/input/train1/Train/high/543.png
# /kaggle/input/train1/Train/high/737.png
# /kaggle/input/train1/Train/high/70.png
# /kaggle/input/train1/Train/high/162.png
# /kaggle/input/train1/Train/high/517.png
# /kaggle/input/train1/Train/high/634.png
# /kaggle/input/train1/Train/high/186.png
# /kaggle/input/train1/Train/high/73.png
# /kaggle/input/train1/Train/high/92.png
# /kaggle/input/train1/Train/high/542.png
# /kaggle/input/train1/Train/high/766.png
# /kaggle/input/train1/Train/high/261.png
# /kaggle/input/train1/Train/high/167.png
# /kaggle/input/train1/Train/high/628.png
# /kaggle/input/train1/Train/high/506.png
# /kaggle/input/train1/Train/high/562.png
# /kaggle/input/train1/Train/high/681.png
# /kaggle/input/train1/Train/high/204.png
# /kaggle/input/train1/Train/high/646.png
# /kaggle/input/train1/Train/high/75.png
# /kaggle/input/train1/Train/high/744.png
# /kaggle/input/train1/Train/high/538.png
# /kaggle/input/train1/Train/high/651.png
# /kaggle/input/train1/Train/high/89.png
# /kaggle/input/train1/Train/high/752.png
# /kaggle/input/train1/Train/high/550.png
# /kaggle/input/train1/Train/high/615.png
# /kaggle/input/train1/Train/high/605.png
# /kaggle/input/train1/Train/high/213.png
# /kaggle/input/train1/Train/high/505.png
# /kaggle/input/train1/Train/high/114.png
# /kaggle/input/train1/Train/high/185.png
# /kaggle/input/train1/Train/high/240.png
# /kaggle/input/train1/Train/high/344.png
# /kaggle/input/train1/Train/high/759.png
# /kaggle/input/train1/Train/high/176.png
# /kaggle/input/train1/Train/high/660.png
# /kaggle/input/train1/Train/high/727.png
# /kaggle/input/train1/Train/high/95.png
# /kaggle/input/train1/Train/high/97.png
# /kaggle/input/train1/Train/high/124.png
# /kaggle/input/train1/Train/high/119.png
# /kaggle/input/train1/Train/high/654.png
# /kaggle/input/train1/Train/high/100.png
# /kaggle/input/train1/Train/high/211.png
# /kaggle/input/train1/Train/high/500.png
# /kaggle/input/train1/Train/high/76.png
# /kaggle/input/train1/Train/high/193.png
# /kaggle/input/train1/Train/high/608.png
# /kaggle/input/train1/Train/high/191.png
# /kaggle/input/train1/Train/high/528.png
# /kaggle/input/train1/Train/high/623.png
# /kaggle/input/train1/Train/high/642.png
# /kaggle/input/train1/Train/high/138.png
# /kaggle/input/train1/Train/high/629.png
# /kaggle/input/train1/Train/high/225.png
# /kaggle/input/train1/Train/high/561.png
# /kaggle/input/train1/Train/high/588.png
# /kaggle/input/train1/Train/high/492.png
# /kaggle/input/train1/Train/high/43.png
# /kaggle/input/train1/Train/high/229.png
# /kaggle/input/train1/Train/high/129.png
# /kaggle/input/train1/Train/high/580.png
# /kaggle/input/train1/Train/high/171.png
# /kaggle/input/train1/Train/high/682.png
# /kaggle/input/train1/Train/high/145.png
# /kaggle/input/train1/Train/high/40.png
# /kaggle/input/train1/Train/high/209.png
# /kaggle/input/train1/Train/high/575.png
# /kaggle/input/train1/Train/high/33.png
# /kaggle/input/train1/Train/high/126.png
# /kaggle/input/train1/Train/high/147.png
# /kaggle/input/train1/Train/high/688.png
# /kaggle/input/train1/Train/high/468.png
# /kaggle/input/train1/Train/high/9.png
# /kaggle/input/train1/Train/high/604.png
# /kaggle/input/train1/Train/high/102.png
# /kaggle/input/train1/Train/high/254.png
# /kaggle/input/train1/Train/high/658.png
# /kaggle/input/train1/Train/high/647.png
# /kaggle/input/train1/Train/high/689.png
# /kaggle/input/train1/Train/high/233.png
# /kaggle/input/train1/Train/high/200.png
# /kaggle/input/train1/Train/high/743.png
# /kaggle/input/train1/Train/high/713.png
# /kaggle/input/train1/Train/high/546.png
# /kaggle/input/train1/Train/high/56.png
# /kaggle/input/train1/Train/high/515.png
# /kaggle/input/train1/Train/high/578.png
# /kaggle/input/train1/Train/high/116.png
# /kaggle/input/train1/Train/high/555.png
# /kaggle/input/train1/Train/high/533.png
# /kaggle/input/train1/Train/high/488.png
# /kaggle/input/train1/Train/high/80.png
# /kaggle/input/train1/Train/high/698.png
# /kaggle/input/train1/Train/high/130.png
# /kaggle/input/train1/Train/high/592.png
# /kaggle/input/train1/Train/high/586.png
# /kaggle/input/train1/Train/high/522.png
# /kaggle/input/train1/Train/high/50.png
# /kaggle/input/train1/Train/high/607.png
# /kaggle/input/train1/Train/high/779.png
# /kaggle/input/train1/Train/high/199.png
# /kaggle/input/train1/Train/high/112.png
# /kaggle/input/train1/Train/high/763.png
# /kaggle/input/train1/Train/high/788.png
# /kaggle/input/train1/Train/high/501.png
# /kaggle/input/train1/Train/high/723.png
# /kaggle/input/train1/Train/high/747.png
# /kaggle/input/train1/Train/high/552.png
# /kaggle/input/train1/Train/high/775.png
# /kaggle/input/train1/Train/high/93.png
# /kaggle/input/train1/Train/high/150.png
# /kaggle/input/train1/Train/high/774.png
# /kaggle/input/train1/Train/high/113.png
# /kaggle/input/train1/Train/high/741.png
# /kaggle/input/train1/Train/high/59.png
# /kaggle/input/train1/Train/high/674.png
# /kaggle/input/train1/Train/high/785.png
# /kaggle/input/train1/Train/high/169.png
# /kaggle/input/train1/Train/high/529.png
# /kaggle/input/train1/Train/high/194.png
# /kaggle/input/train1/Train/high/136.png
# /kaggle/input/train1/Train/high/198.png
# /kaggle/input/train1/Train/high/724.png
# /kaggle/input/train1/Train/high/683.png
# /kaggle/input/train1/Train/high/640.png
# /kaggle/input/train1/Train/high/14.png
# /kaggle/input/train1/Train/high/784.png
# /kaggle/input/train1/Train/high/576.png
# /kaggle/input/train1/Train/high/574.png
# /kaggle/input/train1/Train/high/701.png
# /kaggle/input/train1/Train/high/484.png
# /kaggle/input/train1/Train/high/39.png
# /kaggle/input/train1/Train/high/610.png
# /kaggle/input/train1/Train/high/132.png
# /kaggle/input/train1/Train/high/781.png
# /kaggle/input/train1/Train/high/715.png
# /kaggle/input/train1/Train/high/549.png
# /kaggle/input/train1/Train/high/777.png
# /kaggle/input/train1/Train/high/696.png
# /kaggle/input/train1/Train/high/609.png
# /kaggle/input/train1/Train/high/107.png
# /kaggle/input/train1/Train/high/262.png
# /kaggle/input/train1/Train/high/215.png
# /kaggle/input/train1/Train/high/769.png
# /kaggle/input/train1/Train/high/614.png
# /kaggle/input/train1/Train/high/471.png
# /kaggle/input/train1/Train/high/83.png
# /kaggle/input/train1/Train/high/597.png
# /kaggle/input/train1/Train/high/473.png
# /kaggle/input/train1/Train/high/587.png
# /kaggle/input/train1/Train/high/770.png
# /kaggle/input/train1/Train/high/731.png
# /kaggle/input/train1/Train/high/691.png
# /kaggle/input/train1/Train/high/38.png
# /kaggle/input/train1/Train/high/151.png
# /kaggle/input/train1/Train/high/2.png
# /kaggle/input/train1/Train/high/530.png
# /kaggle/input/train1/Train/high/702.png
# /kaggle/input/train1/Train/high/10.png
# /kaggle/input/train1/Train/high/598.png
# /kaggle/input/train1/Train/high/82.png
# /kaggle/input/train1/Train/high/460.png
# /kaggle/input/train1/Train/high/242.png
# /kaggle/input/train1/Train/high/251.png
# /kaggle/input/train1/Train/high/174.png
# /kaggle/input/train1/Train/high/250.png
# /kaggle/input/train1/Train/high/131.png
# /kaggle/input/train1/Train/high/36.png
# /kaggle/input/train1/Train/high/157.png
# /kaggle/input/train1/Train/high/143.png
# /kaggle/input/train1/Train/high/221.png
# /kaggle/input/train1/Train/high/746.png
# /kaggle/input/train1/Train/high/570.png
# /kaggle/input/train1/Train/high/700.png
# /kaggle/input/train1/Train/high/152.png
# /kaggle/input/train1/Train/high/137.png
# /kaggle/input/train1/Train/high/556.png
# /kaggle/input/train1/Train/high/81.png
# /kaggle/input/train1/Train/high/239.png
# /kaggle/input/train1/Train/high/58.png
# /kaggle/input/train1/Train/high/661.png
# /kaggle/input/train1/Train/high/483.png
# /kaggle/input/train1/Train/high/764.png
# /kaggle/input/train1/Train/high/732.png
# /kaggle/input/train1/Train/high/122.png
# /kaggle/input/train1/Train/high/639.png
# /kaggle/input/train1/Train/high/684.png
# /kaggle/input/train1/Train/high/712.png
# /kaggle/input/train1/Train/high/735.png
# /kaggle/input/train1/Train/high/734.png
# /kaggle/input/train1/Train/high/722.png
# /kaggle/input/train1/Train/high/187.png
# /kaggle/input/train1/Train/high/106.png
# /kaggle/input/train1/Train/high/585.png
# /kaggle/input/train1/Train/high/117.png
# /kaggle/input/train1/Train/high/220.png
# /kaggle/input/train1/Train/high/617.png
# /kaggle/input/train1/Train/high/667.png
# /kaggle/input/train1/Train/high/244.png
# /kaggle/input/train1/Train/high/263.png
# /kaggle/input/train1/Train/high/650.png
# /kaggle/input/train1/Train/high/594.png
# /kaggle/input/train1/Train/high/680.png
# /kaggle/input/train1/Train/high/572.png
# /kaggle/input/train1/Train/high/18.png
# /kaggle/input/train1/Train/high/63.png
# /kaggle/input/train1/Train/high/534.png
# /kaggle/input/train1/Train/high/745.png
# /kaggle/input/train1/Train/high/264.png
# /kaggle/input/train1/Train/high/21.png
# /kaggle/input/train1/Train/high/495.png
# /kaggle/input/train1/Train/high/12.png
# /kaggle/input/train1/Train/high/739.png
# /kaggle/input/train1/Train/high/514.png
# /kaggle/input/train1/Train/high/616.png
# /kaggle/input/train1/Train/high/720.png
# /kaggle/input/train1/Train/high/98.png
# /kaggle/input/train1/Train/high/524.png
# /kaggle/input/train1/Train/high/127.png
# /kaggle/input/train1/Train/high/666.png
# /kaggle/input/train1/Train/high/553.png
# /kaggle/input/train1/Train/high/219.png
# /kaggle/input/train1/Train/high/184.png
# /kaggle/input/train1/Train/high/782.png
# /kaggle/input/train1/Train/high/757.png
# /kaggle/input/train1/Train/high/627.png
# /kaggle/input/train1/Train/high/751.png
# /kaggle/input/train1/Train/high/28.png
# /kaggle/input/train1/Train/high/490.png
# /kaggle/input/train1/Train/high/464.png
# /kaggle/input/train1/Train/high/202.png
# /kaggle/input/train1/Train/high/247.png
# /kaggle/input/train1/Train/high/758.png
# /kaggle/input/train1/Train/high/469.png
# /kaggle/input/train1/Train/high/476.png
# /kaggle/input/train1/Train/high/481.png
# /kaggle/input/train1/Train/high/559.png
# /kaggle/input/train1/Train/high/625.png
# /kaggle/input/train1/Train/high/67.png
# /kaggle/input/train1/Train/high/96.png
# /kaggle/input/train1/Train/high/243.png
# /kaggle/input/train1/Train/high/502.png
# /kaggle/input/train1/Train/high/690.png
# /kaggle/input/train1/Train/high/733.png
# /kaggle/input/train1/Train/high/159.png
# /kaggle/input/train1/Train/high/662.png
# /kaggle/input/train1/Train/high/563.png
# /kaggle/input/train1/Train/high/551.png
# /kaggle/input/train1/Train/high/685.png
# /kaggle/input/train1/Train/high/554.png
# /kaggle/input/train1/Train/high/596.png
# /kaggle/input/train1/Train/high/246.png
# /kaggle/input/train1/Train/high/195.png
# /kaggle/input/train1/Train/high/105.png
# /kaggle/input/train1/Train/high/479.png
# /kaggle/input/train1/Train/high/612.png
# /kaggle/input/train1/Train/high/125.png
# /kaggle/input/train1/Train/high/121.png
# /kaggle/input/train1/Train/high/216.png
# /kaggle/input/train1/Train/high/69.png
# /kaggle/input/train1/Train/high/154.png
# /kaggle/input/train1/Train/high/637.png
# /kaggle/input/train1/Train/high/267.png
# /kaggle/input/train1/Train/high/663.png
# /kaggle/input/train1/Train/high/241.png
# /kaggle/input/train1/Train/high/188.png
# /kaggle/input/train1/Train/high/716.png
# /kaggle/input/train1/Train/high/86.png
# /kaggle/input/train1/Train/high/776.png
# /kaggle/input/train1/Train/high/258.png
# /kaggle/input/train1/Train/high/77.png
# /kaggle/input/train1/Train/high/498.png
# /kaggle/input/train1/Train/high/265.png
# /kaggle/input/train1/Train/high/638.png
# /kaggle/input/train1/Train/high/103.png
# /kaggle/input/train1/Train/high/144.png
# /kaggle/input/train1/Train/high/472.png
# /kaggle/input/train1/Train/high/695.png
# /kaggle/input/train1/Train/high/644.png
# /kaggle/input/train1/Train/high/540.png
# /kaggle/input/train1/Train/high/109.png
# /kaggle/input/train1/Train/high/496.png
# /kaggle/input/train1/Train/high/714.png
# /kaggle/input/train1/Train/high/697.png
# /kaggle/input/train1/Train/high/567.png
# /kaggle/input/train1/Train/high/526.png
# /kaggle/input/train1/Train/high/527.png
# /kaggle/input/train1/Train/high/648.png
# /kaggle/input/train1/Train/high/595.png
# /kaggle/input/train1/Train/high/573.png
# /kaggle/input/train1/Train/high/74.png
# /kaggle/input/train1/Train/high/653.png
# /kaggle/input/train1/Train/high/525.png
# /kaggle/input/train1/Train/high/120.png
# /kaggle/input/train1/Train/high/630.png
# /kaggle/input/train1/Train/high/118.png
# /kaggle/input/train1/Train/high/772.png
# /kaggle/input/train1/Train/high/670.png
# /kaggle/input/train1/Train/high/17.png
# /kaggle/input/train1/Train/high/53.png
# /kaggle/input/train1/Train/high/486.png
# /kaggle/input/train1/Train/high/196.png
# /kaggle/input/train1/Train/high/626.png
# /kaggle/input/train1/Train/high/571.png
# /kaggle/input/train1/Train/high/160.png
# /kaggle/input/train1/Train/high/671.png
# /kaggle/input/train1/Train/high/140.png
# /kaggle/input/train1/Train/high/620.png
# /kaggle/input/train1/Train/high/736.png
# /kaggle/input/train1/Train/high/52.png
# /kaggle/input/train1/Train/high/5.png
# /kaggle/input/train1/Train/high/139.png
# /kaggle/input/train1/Train/high/172.png
# /kaggle/input/train1/Train/high/64.png
# /kaggle/input/train1/Train/high/719.png
# /kaggle/input/train1/Train/high/16.png
# /kaggle/input/train1/Train/high/545.png
# /kaggle/input/train1/Train/high/725.png
# /kaggle/input/train1/Train/high/328.png
# /kaggle/input/train1/Train/high/643.png
# /kaggle/input/train1/Train/high/760.png
# /kaggle/input/train1/Train/high/203.png
# /kaggle/input/train1/Train/high/489.png
# /kaggle/input/train1/Train/high/45.png
# /kaggle/input/train1/Train/high/24.png
# /kaggle/input/train1/Train/high/548.png
# /kaggle/input/train1/Train/high/88.png
# /kaggle/input/train1/Train/high/649.png
# /kaggle/input/train1/Train/high/624.png
# /kaggle/input/train1/Train/high/115.png
# /kaggle/input/train1/Train/high/249.png
# /kaggle/input/train1/Train/high/128.png
# /kaggle/input/train1/Train/high/668.png
# /kaggle/input/train1/Train/high/583.png
# /kaggle/input/train1/Train/high/710.png
# /kaggle/input/train1/Train/high/6.png
# /kaggle/input/train1/Train/high/87.png
# /kaggle/input/train1/Train/high/686.png
# /kaggle/input/train1/Train/high/787.png
# /kaggle/input/train1/Train/high/51.png
# /kaggle/input/train1/Train/high/703.png
# /kaggle/input/train1/Train/high/728.png
# /kaggle/input/train1/Train/high/591.png
# /kaggle/input/train1/Train/high/101.png
# /kaggle/input/train1/Train/high/606.png
# /kaggle/input/train1/Train/high/717.png
# /kaggle/input/train1/Train/high/135.png
# /kaggle/input/train1/Train/high/482.png
# /kaggle/input/train1/Train/high/740.png
# /kaggle/input/train1/Train/high/512.png
# /kaggle/input/train1/Train/high/123.png
# /kaggle/input/train1/Train/high/91.png
# /kaggle/input/train1/Train/high/504.png
# /kaggle/input/train1/Train/high/230.png
# /kaggle/input/train1/Train/high/738.png
# /kaggle/input/train1/Train/high/478.png
# /kaggle/input/train1/Train/high/44.png
# /kaggle/input/train1/Train/high/189.png
# /kaggle/input/train1/Train/high/541.png
# /kaggle/input/train1/Train/high/601.png
# /kaggle/input/train1/Train/high/730.png
# /kaggle/input/train1/Train/high/68.png
# /kaggle/input/train1/Train/high/180.png
# /kaggle/input/train1/Train/high/46.png
# /kaggle/input/train1/Train/high/508.png
# /kaggle/input/train1/Train/high/499.png
# /kaggle/input/train1/Train/high/711.png
# /kaggle/input/train1/Train/high/664.png
# /kaggle/input/train1/Train/high/470.png
# /kaggle/input/train1/Train/high/57.png
# /kaggle/input/train1/Train/high/84.png
# /kaggle/input/train1/Train/high/475.png
# /kaggle/input/train1/Train/high/564.png
# /kaggle/input/train1/Train/high/687.png
# /kaggle/input/train1/Train/high/15.png
# /kaggle/input/train1/Train/high/210.png
# /kaggle/input/train1/Train/high/252.png
# /kaggle/input/train1/Train/high/531.png
# /kaggle/input/train1/Train/high/507.png
# /kaggle/input/train1/Train/high/704.png
# /kaggle/input/train1/Train/high/565.png
# /kaggle/input/train1/Train/high/679.png
# /kaggle/input/train1/Train/high/523.png
# /kaggle/input/train1/Train/high/183.png
# /kaggle/input/train1/Train/high/678.png
# /kaggle/input/train1/Train/high/450.png
# /kaggle/input/train1/Train/high/485.png
# /kaggle/input/train1/Train/high/708.png
# /kaggle/input/train1/Train/high/569.png
# /kaggle/input/train1/Train/high/622.png
# /kaggle/input/train1/Train/high/537.png
# /kaggle/input/train1/Train/high/783.png
# /kaggle/input/train1/Train/high/60.png
# /kaggle/input/train1/Train/high/235.png
# /kaggle/input/train1/Train/high/99.png
# /kaggle/input/train1/Train/high/765.png
# /kaggle/input/train1/Train/high/593.png
# /kaggle/input/train1/Train/high/676.png
# /kaggle/input/train1/Train/high/228.png
# /kaggle/input/train1/Train/high/27.png
# /kaggle/input/train1/Train/high/237.png
# /kaggle/input/train1/Train/high/692.png
# /kaggle/input/train1/Train/high/474.png
# /kaggle/input/train1/Train/high/201.png
# /kaggle/input/train1/Train/high/539.png
# /kaggle/input/train1/Train/high/773.png
# /kaggle/input/train1/Train/high/78.png
# /kaggle/input/train1/Train/high/212.png
# /kaggle/input/train1/Train/high/47.png
# /kaggle/input/train1/Train/high/786.png
# /kaggle/input/train1/Train/high/207.png
# /kaggle/input/train1/Train/high/149.png
# /kaggle/input/train1/Train/high/487.png
# /kaggle/input/train1/Train/high/13.png
# /kaggle/input/train1/Train/high/535.png
# /kaggle/input/train1/Train/high/260.png
# /kaggle/input/train1/Train/high/253.png
# /kaggle/input/train1/Train/high/206.png
# /kaggle/input/train1/Train/high/789.png
# /kaggle/input/train1/Train/high/557.png
# /kaggle/input/train1/Train/high/613.png
# /kaggle/input/train1/Train/high/600.png
# /kaggle/input/train1/Train/high/342.png
# /kaggle/input/train1/Train/high/721.png
# /kaggle/input/train1/Train/high/694.png
# /kaggle/input/train1/Train/high/590.png
# /kaggle/input/train1/Train/high/566.png
# /kaggle/input/train1/Train/high/259.png
# /kaggle/input/train1/Train/high/25.png
# /kaggle/input/train1/Train/high/54.png
# /kaggle/input/train1/Train/high/558.png
# /kaggle/input/train1/Train/high/611.png
# /kaggle/input/train1/Train/high/62.png
# /kaggle/input/train1/Train/high/699.png
# /kaggle/input/train1/Train/high/750.png
# /kaggle/input/train1/Train/high/141.png
# /kaggle/input/train1/Train/high/693.png
# /kaggle/input/train1/Train/high/532.png
# /kaggle/input/train1/Train/high/560.png
# /kaggle/input/train1/Train/high/110.png
# /kaggle/input/train1/Train/high/544.png
# /kaggle/input/train1/Train/high/26.png
# /kaggle/input/train1/Train/high/568.png
# /kaggle/input/train1/Train/high/633.png
# /kaggle/input/train1/Train/high/729.png
# /kaggle/input/train1/Train/high/257.png
# /kaggle/input/train1/Train/high/477.png
# /kaggle/input/train1/Train/high/42.png
# /kaggle/input/train1/Train/high/175.png
# /kaggle/input/train1/Train/high/494.png
# /kaggle/input/train1/Train/high/659.png
# /kaggle/input/train1/Train/high/497.png

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.optim as optim
from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import CosineAnnealingLR

def calculate_psnr(output, target, max_val=1.0):
    mse = F.mse_loss(output, target)
    psnr = 20 * torch.log10(max_val / torch.sqrt(mse))
    return psnr

class LowLightDataset(Dataset):
    def __init__(self, low_dir, high_dir, transform=None):
        self.low_dir = low_dir
        self.high_dir = high_dir
        self.low_images = os.listdir(low_dir)
        self.high_images = os.listdir(high_dir)
        self.transform = transform

        if len(self.low_images) != len(self.high_images):
            print("Warning: The number of images in low_dir and high_dir are not the same.")
            self.low_images = self.low_images[:min(len(self.low_images), len(self.high_images))]
            self.high_images = self.high_images[:min(len(self.low_images), len(self.high_images))]

    def __len__(self):
        return len(self.low_images)

    def __getitem__(self, idx):
        low_img_path = os.path.join(self.low_dir, self.low_images[idx])
        high_img_path = os.path.join(self.high_dir, self.high_images[idx])

        low_image = Image.open(low_img_path).convert("RGB")
        high_image = Image.open(high_img_path).convert("RGB")

        if self.transform:
            low_image = self.transform(low_image)
            high_image = self.transform(high_image)

        return low_image, high_image

transform = transforms.Compose([
    transforms.ToTensor()
])

train_low_dir = '/kaggle/input/dataset00/augmented_Train/augmented/low'
train_high_dir = '/kaggle/input/dataset00/augmented_Train/augmented/high'
val_low_dir = '/kaggle/input/dataset00/augmented_Train/val/low'
val_high_dir = '/kaggle/input/dataset00/augmented_Train/val/high'

train_dataset = LowLightDataset(train_low_dir, train_high_dir, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
val_dataset = LowLightDataset(val_low_dir, val_high_dir, transform=transform)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=True)

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self, in_channels, out_channels, features=[64, 128, 256, 512]):
        super().__init__()
        self.ups = nn.ModuleList()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Down part
        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        # Up part
        for feature in reversed(features):
            self.ups.append(nn.ConvTranspose2d(feature*2, feature, kernel_size=2, stride=2))
            self.ups.append(DoubleConv(feature*2, feature))

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        # Down part
        for down in self.downs:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)

        # Up part
        skip_connections = skip_connections[::-1]
        for idx in range(0, len(self.ups), 2):
            x = self.ups[idx](x)
            skip_connection = skip_connections[idx//2]

            if x.shape != skip_connection.shape:
                x = torch.nn.functional.interpolate(x, size=skip_connection.shape[2:], mode='bilinear')

            concat_skip = torch.cat((skip_connection, x), dim=1)
            x = self.ups[idx+1](concat_skip)

        return self.final_conv(x)
    
model = UNet(in_channels=3, out_channels=3)

class MLPBlock(nn.Module):
    def __init__(self, in_channels, hidden_channels):
        super(MLPBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, hidden_channels, kernel_size=1)
        self.gelu = nn.GELU()
        self.conv2 = nn.Conv2d(hidden_channels, in_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        x1 = self.conv1(x)
        x1 = self.gelu(x1)
        x1 = self.conv2(x1)
        x1 = self.sigmoid(x1)
        x = x + x1
        return x

class PixelWarriorNetwork(nn.Module):
    def __init__(self, in_channels=3, num_blocks=6, num_out_channels=3, features=[64, 128, 256, 512]):
        super(PixelWarriorNetwork, self).__init__()
        self.downsampler = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=2, padding=1)
        self.mlp_blocks = nn.ModuleList([MLPBlock(in_channels, in_channels * 2) for _ in range(num_blocks)])
        self.upsampler = nn.ConvTranspose2d(in_channels, in_channels, kernel_size=4, stride=2, padding=1)
        self.unet = UNet(in_channels, num_out_channels, features)

    def forward(self, x):
        x = self.downsampler(x)
        for block in self.mlp_blocks:
            x = block(x)
        x = self.upsampler(x)
        x = self.unet(x)
        return x

model = PixelWarriorNetwork(in_channels=3, num_blocks=6, num_out_channels=3, features=[64, 128, 256, 512])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
import torch

model = PixelWarriorNetwork(in_channels=3)

model_path = "/kaggle/input/vlgfinal1/finalmodel1 (1).pth"
model.load_state_dict(torch.load(model_path))
model.eval()

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
import math
import tqdm as tqdm
from torch.cuda.amp import autocast, GradScaler

# Assuming you have already defined the UNet and LowLightDataset classes

# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)


# Add CosineAnnealingLR scheduler
scheduler = CosineAnnealingLR(optimizer, T_max=10, eta_min=0.000001)

scaler = GradScaler()
num_epochs = 2

for epoch in tqdm.tqdm(range(num_epochs)):
    model.train()
    running_loss = 0.0
    running_psnr = 0.0

    for low_images, high_images in train_loader:
        low_images = low_images.to(device)
        high_images = high_images.to(device)

        optimizer.zero_grad()

        with autocast():
            outputs = model(low_images)
            loss = criterion(outputs, high_images)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        psnr = calculate_psnr(outputs, high_images)
        running_psnr += psnr.item()

        del low_images, high_images, outputs, loss, psnr
        torch.cuda.empty_cache()

    epoch_loss = running_loss / len(train_loader)
    epoch_psnr = running_psnr / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, PSNR: {epoch_psnr:.2f} dB")
    
    model.eval()
    val_loss = 0.0
    val_psnr = 0.0
    with torch.no_grad():
        for low_images, high_images in val_loader:
            low_images = low_images.to(device)
            high_images = high_images.to(device)

            with autocast():
                outputs = model(low_images)
                loss = criterion(outputs, high_images)

            val_loss += loss.item() * low_images.size(0)
            psnr = calculate_psnr(outputs, high_images)
            val_psnr += psnr.item() * low_images.size(0)

            del low_images, high_images, outputs, loss, psnr
            torch.cuda.empty_cache()

    val_loss /= len(val_loader.dataset)
    val_psnr /= len(val_loader.dataset)
#     print(f'Validation Loss: {val_loss:.4f}, Validation PSNR: {val_psnr:.2f} dB')
    
    scheduler.step()

torch.save(model.state_dict(), "finalmodel1.pth")
# Out:
#   0%|          | 0/2 [00:13<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 28
#      25 running_loss = 0.0
#      26 running_psnr = 0.0
# ---> 28 for low_images, high_images in train_loader:
#      29     low_images = low_images.to(device)
#      30     high_images = high_images.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[20], line 39, in LowLightDataset.__getitem__(self, idx)
#      36 high_img_path = os.path.join(self.high_dir, self.high_images[idx])
#      38 low_image = Image.open(low_img_path).convert("RGB")
# ---> 39 high_image = Image.open(high_img_path).convert("RGB")
#      41 if self.transform:
#      42     low_image = self.transform(low_image)
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:945, in Image.convert(self, mode, matrix, dither, palette, colors)
#     943         mode = "RGBA"
#     944 if not mode or (mode == self.mode and not matrix):
# --> 945     return self.copy()
#     947 if matrix:
#     948     # matrix conversion
#     949     if mode not in ("L", "RGB"):
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:1202, in Image.copy(self)
#    1194 """
#    1195 Copies this image. Use this method if you wish to paste things
#    1196 into an image, but still retain the original.
#    (...)
#    1199 :returns: An :py:class:`~PIL.Image.Image` object.
#    1200 """
#    1201 self.load()
# -> 1202 return self._new(self.im.copy())
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from PIL import Image

model.eval()
transform = transforms.Compose([
    transforms.Resize((400, 600)),
    transforms.ToTensor()
])

input_image_path = '/kaggle/input/train1/Train/low/12.png'
ground_truth_path = '/kaggle/input/train1/Train/high/12.png'

input_image = Image.open(input_image_path).convert('RGB')
ground_truth_image = Image.open(ground_truth_path).convert('RGB')

# Display the original input image, ground truth image, and enhanced image
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 7))
ax1.imshow(input_image)
ax1.set_title('Original Image')
ax1.axis('off')

ax2.imshow(ground_truth_image)
ax2.set_title('Ground Truth Image')
ax2.axis('off')

input_tensor = transform(input_image).unsqueeze(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
input_tensor = input_tensor.to(device)

with torch.no_grad():
    enhanced_tensor = model(input_tensor)
    enhanced_tensor = enhanced_tensor.cpu()

enhanced_image = transforms.ToPILImage()(enhanced_tensor.squeeze())
ax3.imshow(enhanced_image)
ax3.set_title('Enhanced Image')
ax3.axis('off')

plt.tight_layout()
plt.show()

# %%
import torch

def psnr(img1, img2):
    mse = torch.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1.0
    psnr = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr

import random
import cv2
import os
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
from torchvision.transforms.functional import pil_to_tensor, to_pil_image

def psnr(img1, img2):
    mse = torch.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1.0
    psnr = 20 * torch.log10(max_pixel / torch.sqrt(mse))
    return psnr

# Rest of your code...

model.eval()
transform = transforms.Compose([
    transforms.Resize((400, 592)),
    transforms.ToTensor() 
])
model.eval()

low_dir = '/kaggle/input/train1/Train/low'
high_dir = '/kaggle/input/train1/Train/high'

low_images = os.listdir(low_dir)

random_images = random.sample(low_images,10)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

psnr_values = []

for image_name in random_images:
    input_image_path = os.path.join(low_dir, image_name)
    high_image_path = os.path.join(high_dir, image_name)
    input_image = Image.open(input_image_path).convert('RGB')
    input_tensor = transform(input_image).unsqueeze(0).to(device)
    with torch.no_grad():
        enhanced_tensor = model(input_tensor).cpu()

    enhanced_image = transforms.ToPILImage()(enhanced_tensor.squeeze())

    original_image = cv2.imread(high_image_path)
    original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    
    fig, axs = plt.subplots(1, 3, figsize=(10, 5))  
    axs[0].imshow(input_image)
    axs[0].set_title('Low Light')
    axs[0].axis('off')
    
    axs[1].imshow(enhanced_image)
    axs[1].set_title('Enhanced')
    axs[1].axis('off')
    
    axs[2].imshow(original_image_rgb)
    axs[2].set_title('Ground Truth')
    axs[2].axis('off')
    
    plt.show()
    
    original_tensor = transform(Image.fromarray(original_image_rgb)).unsqueeze(0)
    psnr_value = psnr(original_tensor, enhanced_tensor)
    psnr_values.append(psnr_value)
    print(f'PSNR: {psnr_value:.2f} dB')
average_psnr = sum(psnr_values) / len(psnr_values)
print(f'Average PSNR: {average_psnr:.2f} dB')
# Out:
# PSNR: 18.16 dB
# PSNR: 15.38 dB
# PSNR: 13.77 dB
# PSNR: 17.01 dB
# PSNR: 19.61 dB
# PSNR: 15.99 dB
# PSNR: 21.33 dB
# PSNR: 13.49 dB
# PSNR: 6.25 dB
# PSNR: 10.73 dB
# Average PSNR: 15.17 dB
